# %% [markdown]
# * Construcción de una red neuronal para la **clasificación de tipos de flores**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Carga de datos

# %%
###################################################
# 1. Load data
###################################################
datos = pd.read_csv('/home/walter/Documents/serie-notas/z_data/datos_curso_redes_neuronales/Iris.csv')
datos.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
###################################################
# 2. Preprocessing
###################################################
target = 'class'
features = ['sepallength', 'sepalwidth','petallength','petalwidth']

X = datos[features]
y = datos[target]

# Encoding de target, para responder al problema de 3 categorías
encoder = LabelEncoder()
y_cat = encoder.fit_transform(y)
y_cat = to_categorical(y_cat)

# separación train-test
X_train, X_test, y_train, y_test=train_test_split(X, y_cat, test_size=0.20)

# normalizo tanto los datos  X de entrenamiento como los de testeo
normalizador = StandardScaler()
X_train = normalizador.fit_transform(X_train)
X_test = normalizador.transform(X_test)
X_train[0:5]
# Out:
# array([[-0.89831615,  1.6874758 , -1.22385162, -1.14556954],
#        [-1.02039763,  0.53430327, -1.27975653, -1.27787786],
#        [-0.04374586,  2.14874481, -1.39156635, -1.27787786],
#        [-1.26456057,  0.07303426, -1.16794671, -1.27787786],
#        [-1.50872351,  0.07303426, -1.22385162, -1.27787786]])

# %%
###################################################
# 3. Design NN
###################################################
# 1. Número de neuronas en capa de entrada: 4 (una por feature)
# 2. Número de neuronas en capa de salida: 3 (una por categoría)
# 3. Capas ocultas: 1
# 4. Nro neuronas en capa oculta : 1
# 5. Función de activación de la capa oculta: tanh
# 6. Función de activación capa output: sigmoide
# 7. Algoritmo: SGD (descenso del gradiente estocástico)
# 8. Función de error: MSE
# 9. Medida de perfomance: ACCURACY

# parámetros
nIn = X_train.shape[1] # 1 per feature
nOut = y_train.shape[1] # 3 values for response
ocultas = 1

# diseño
model = Sequential()
model.add(Dense(ocultas, input_shape=[nIn], activation='tanh'))
model.add(Dense(nOut, activation='sigmoid'))
model.summary()  #-- muestra la cantidad de parámetros de la red
model.compile(optimizer=SGD(lr=0.1), loss='mse', metrics='accuracy')
#-- se utilizará SGD (descenso de gradiente estocástico),
#-- MSE (error cuadrático medio) y ACCURACY como medida de performance
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 1)                 5
#
#  dense_7 (Dense)             (None, 3)                 6
#
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________

# %%
###################################################
# 4. Train
###################################################
model.fit(X_train, y_train, epochs=100, batch_size=20);
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 867us/step - loss: 0.3343 - accuracy: 0.0167
# Epoch 2/100
# 6/6 [==============================] - 0s 719us/step - loss: 0.3254 - accuracy: 0.0250
# Epoch 3/100
# 6/6 [==============================] - 0s 919us/step - loss: 0.3166 - accuracy: 0.1917
# Epoch 4/100
# 6/6 [==============================] - 0s 727us/step - loss: 0.3079 - accuracy: 0.2000
# Epoch 5/100
# 6/6 [==============================] - 0s 941us/step - loss: 0.2994 - accuracy: 0.2250
# Epoch 6/100
# 6/6 [==============================] - 0s 875us/step - loss: 0.2910 - accuracy: 0.2417
# Epoch 7/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2829 - accuracy: 0.2417
# Epoch 8/100
# 6/6 [==============================] - 0s 780us/step - loss: 0.2749 - accuracy: 0.2667
# Epoch 9/100
# 6/6 [==============================] - 0s 773us/step - loss: 0.2673 - accuracy: 0.2917
# Epoch 10/100
# 6/6 [==============================] - 0s 878us/step - loss: 0.2600 - accuracy: 0.3083
# Epoch 11/100
# 6/6 [==============================] - 0s 720us/step - loss: 0.2529 - accuracy: 0.3417
# Epoch 12/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2463 - accuracy: 0.3750
# Epoch 13/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2400 - accuracy: 0.4000
# Epoch 14/100
# 6/6 [==============================] - 0s 903us/step - loss: 0.2341 - accuracy: 0.4167
# Epoch 15/100
# 6/6 [==============================] - 0s 958us/step - loss: 0.2284 - accuracy: 0.4500
# Epoch 16/100
# 6/6 [==============================] - 0s 807us/step - loss: 0.2230 - accuracy: 0.4583
# Epoch 17/100
# 6/6 [==============================] - 0s 716us/step - loss: 0.2180 - accuracy: 0.4583
# Epoch 18/100
# 6/6 [==============================] - 0s 892us/step - loss: 0.2133 - accuracy: 0.5083
# Epoch 19/100
# 6/6 [==============================] - 0s 790us/step - loss: 0.2089 - accuracy: 0.5500
# Epoch 20/100
# 6/6 [==============================] - 0s 918us/step - loss: 0.2048 - accuracy: 0.5833
# Epoch 21/100
# 6/6 [==============================] - 0s 910us/step - loss: 0.2010 - accuracy: 0.5833
# Epoch 22/100
# 6/6 [==============================] - 0s 959us/step - loss: 0.1974 - accuracy: 0.6083
# Epoch 23/100
# 6/6 [==============================] - 0s 985us/step - loss: 0.1942 - accuracy: 0.6083
# Epoch 24/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1911 - accuracy: 0.6083
# Epoch 25/100
# 6/6 [==============================] - 0s 894us/step - loss: 0.1882 - accuracy: 0.6083
# Epoch 26/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1856 - accuracy: 0.6167
# Epoch 27/100
# 6/6 [==============================] - 0s 750us/step - loss: 0.1830 - accuracy: 0.6167
# Epoch 28/100
# 6/6 [==============================] - 0s 839us/step - loss: 0.1805 - accuracy: 0.6167
# Epoch 29/100
# 6/6 [==============================] - 0s 654us/step - loss: 0.1783 - accuracy: 0.6333
# Epoch 30/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1760 - accuracy: 0.6333
# Epoch 31/100
# 6/6 [==============================] - 0s 865us/step - loss: 0.1739 - accuracy: 0.6333
# Epoch 32/100
# 6/6 [==============================] - 0s 772us/step - loss: 0.1718 - accuracy: 0.6333
# Epoch 33/100
# 6/6 [==============================] - 0s 750us/step - loss: 0.1699 - accuracy: 0.6333
# Epoch 34/100
# 6/6 [==============================] - 0s 718us/step - loss: 0.1680 - accuracy: 0.6333
# Epoch 35/100
# 6/6 [==============================] - 0s 815us/step - loss: 0.1662 - accuracy: 0.6333
# Epoch 36/100
# 6/6 [==============================] - 0s 667us/step - loss: 0.1644 - accuracy: 0.6333
# Epoch 37/100
# 6/6 [==============================] - 0s 662us/step - loss: 0.1627 - accuracy: 0.6333
# Epoch 38/100
# 6/6 [==============================] - 0s 649us/step - loss: 0.1611 - accuracy: 0.6333
# Epoch 39/100
# 6/6 [==============================] - 0s 714us/step - loss: 0.1595 - accuracy: 0.6583
# Epoch 40/100
# 6/6 [==============================] - 0s 673us/step - loss: 0.1580 - accuracy: 0.6583
# Epoch 41/100
# 6/6 [==============================] - 0s 969us/step - loss: 0.1565 - accuracy: 0.6583
# Epoch 42/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1552 - accuracy: 0.6583
# Epoch 43/100
# 6/6 [==============================] - 0s 678us/step - loss: 0.1538 - accuracy: 0.6667
# Epoch 44/100
# 6/6 [==============================] - 0s 724us/step - loss: 0.1525 - accuracy: 0.6750
# Epoch 45/100
# 6/6 [==============================] - 0s 650us/step - loss: 0.1513 - accuracy: 0.6667
# Epoch 46/100
# 6/6 [==============================] - 0s 699us/step - loss: 0.1501 - accuracy: 0.6583
# Epoch 47/100
# 6/6 [==============================] - 0s 673us/step - loss: 0.1490 - accuracy: 0.6333
# Epoch 48/100
# 6/6 [==============================] - 0s 615us/step - loss: 0.1479 - accuracy: 0.6500
# Epoch 49/100
# 6/6 [==============================] - 0s 681us/step - loss: 0.1469 - accuracy: 0.6250
# Epoch 50/100
# 6/6 [==============================] - 0s 722us/step - loss: 0.1459 - accuracy: 0.6250
# Epoch 51/100
# 6/6 [==============================] - 0s 707us/step - loss: 0.1449 - accuracy: 0.6083
# Epoch 52/100
# 6/6 [==============================] - 0s 757us/step - loss: 0.1440 - accuracy: 0.5583
# Epoch 53/100
# 6/6 [==============================] - 0s 903us/step - loss: 0.1431 - accuracy: 0.6083
# Epoch 54/100
# 6/6 [==============================] - 0s 746us/step - loss: 0.1423 - accuracy: 0.6833
# Epoch 55/100
# 6/6 [==============================] - 0s 695us/step - loss: 0.1415 - accuracy: 0.6833
# Epoch 56/100
# 6/6 [==============================] - 0s 759us/step - loss: 0.1406 - accuracy: 0.6833
# Epoch 57/100
# 6/6 [==============================] - 0s 749us/step - loss: 0.1399 - accuracy: 0.6833
# Epoch 58/100
# 6/6 [==============================] - 0s 712us/step - loss: 0.1392 - accuracy: 0.6833
# Epoch 59/100
# 6/6 [==============================] - 0s 857us/step - loss: 0.1384 - accuracy: 0.6833
# Epoch 60/100
# 6/6 [==============================] - 0s 734us/step - loss: 0.1378 - accuracy: 0.6833
# Epoch 61/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1371 - accuracy: 0.6833
# Epoch 62/100
# 6/6 [==============================] - 0s 689us/step - loss: 0.1365 - accuracy: 0.6833
# Epoch 63/100
# 6/6 [==============================] - 0s 700us/step - loss: 0.1359 - accuracy: 0.6833
# Epoch 64/100
# 6/6 [==============================] - 0s 893us/step - loss: 0.1353 - accuracy: 0.6833
# Epoch 65/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1347 - accuracy: 0.6833
# Epoch 66/100
# 6/6 [==============================] - 0s 743us/step - loss: 0.1341 - accuracy: 0.6833
# Epoch 67/100
# 6/6 [==============================] - 0s 714us/step - loss: 0.1337 - accuracy: 0.6833
# Epoch 68/100
# 6/6 [==============================] - 0s 700us/step - loss: 0.1331 - accuracy: 0.6833
# Epoch 69/100
# 6/6 [==============================] - 0s 670us/step - loss: 0.1326 - accuracy: 0.6833
# Epoch 70/100
# 6/6 [==============================] - 0s 611us/step - loss: 0.1321 - accuracy: 0.6833
# Epoch 71/100
# 6/6 [==============================] - 0s 685us/step - loss: 0.1317 - accuracy: 0.6833
# Epoch 72/100
# 6/6 [==============================] - 0s 734us/step - loss: 0.1312 - accuracy: 0.6833
# Epoch 73/100
# 6/6 [==============================] - 0s 821us/step - loss: 0.1308 - accuracy: 0.6833
# Epoch 74/100
# 6/6 [==============================] - 0s 782us/step - loss: 0.1303 - accuracy: 0.6833
# Epoch 75/100
# 6/6 [==============================] - 0s 831us/step - loss: 0.1299 - accuracy: 0.6833
# Epoch 76/100
# 6/6 [==============================] - 0s 712us/step - loss: 0.1295 - accuracy: 0.6833
# Epoch 77/100
# 6/6 [==============================] - 0s 719us/step - loss: 0.1291 - accuracy: 0.6833
# Epoch 78/100
# 6/6 [==============================] - 0s 708us/step - loss: 0.1288 - accuracy: 0.6833
# Epoch 79/100
# 6/6 [==============================] - 0s 700us/step - loss: 0.1284 - accuracy: 0.6833
# Epoch 80/100
# 6/6 [==============================] - 0s 745us/step - loss: 0.1280 - accuracy: 0.6833
# Epoch 81/100
# 6/6 [==============================] - 0s 700us/step - loss: 0.1277 - accuracy: 0.6833
# Epoch 82/100
# 6/6 [==============================] - 0s 870us/step - loss: 0.1274 - accuracy: 0.6833
# Epoch 83/100
# 6/6 [==============================] - 0s 612us/step - loss: 0.1270 - accuracy: 0.6833
# Epoch 84/100
# 6/6 [==============================] - 0s 850us/step - loss: 0.1267 - accuracy: 0.6833
# Epoch 85/100
# 6/6 [==============================] - 0s 737us/step - loss: 0.1264 - accuracy: 0.6833
# Epoch 86/100
# 6/6 [==============================] - 0s 665us/step - loss: 0.1261 - accuracy: 0.6833
# Epoch 87/100
# 6/6 [==============================] - 0s 790us/step - loss: 0.1258 - accuracy: 0.6833
# Epoch 88/100
# 6/6 [==============================] - 0s 711us/step - loss: 0.1255 - accuracy: 0.6833
# Epoch 89/100
# 6/6 [==============================] - 0s 607us/step - loss: 0.1253 - accuracy: 0.6833
# Epoch 90/100
# 6/6 [==============================] - 0s 927us/step - loss: 0.1250 - accuracy: 0.6833
# Epoch 91/100
# 6/6 [==============================] - 0s 806us/step - loss: 0.1247 - accuracy: 0.6833
# Epoch 92/100
# 6/6 [==============================] - 0s 697us/step - loss: 0.1245 - accuracy: 0.6833
# Epoch 93/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1242 - accuracy: 0.6833
# Epoch 94/100
# 6/6 [==============================] - 0s 759us/step - loss: 0.1240 - accuracy: 0.6833
# Epoch 95/100
# 6/6 [==============================] - 0s 765us/step - loss: 0.1238 - accuracy: 0.6833
# Epoch 96/100
# 6/6 [==============================] - 0s 596us/step - loss: 0.1235 - accuracy: 0.6833
# Epoch 97/100
# 6/6 [==============================] - 0s 721us/step - loss: 0.1233 - accuracy: 0.6833
# Epoch 98/100
# 6/6 [==============================] - 0s 606us/step - loss: 0.1231 - accuracy: 0.6833
# Epoch 99/100
# 6/6 [==============================] - 0s 587us/step - loss: 0.1228 - accuracy: 0.6833
# Epoch 100/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.6833

# %%
###################################################
# 4. Predict (in sample)
###################################################
y_pred = model.predict(X_train)
pd.concat([pd.DataFrame(y_pred), pd.DataFrame(y_train)], axis=1).head(20)
# Out:
# 4/4 [==============================] - 0s 1ms/step
#            0         1         2    0    1    2
# 0   0.803124  0.177942  0.147425  1.0  0.0  0.0
# 1   0.799534  0.179415  0.149063  1.0  0.0  0.0
# 2   0.803795  0.177666  0.147119  1.0  0.0  0.0
# 3   0.792994  0.182070  0.152027  1.0  0.0  0.0
# 4   0.794901  0.181299  0.151165  1.0  0.0  0.0
# 5   0.114873  0.500771  0.556681  0.0  0.0  1.0
# 6   0.113177  0.502637  0.559062  0.0  0.0  1.0
# 7   0.228201  0.410202  0.438860  0.0  1.0  0.0
# 8   0.118202  0.497175  0.552087  0.0  0.0  1.0
# 9   0.113915  0.501821  0.558021  0.0  0.0  1.0
# 10  0.116831  0.498645  0.553966  0.0  1.0  0.0
# 11  0.798391  0.179881  0.149583  1.0  0.0  0.0
# 12  0.118008  0.497382  0.552352  0.0  0.0  1.0
# 13  0.798888  0.179678  0.149357  1.0  0.0  0.0
# 14  0.145936  0.470221  0.517374  0.0  1.0  0.0
# 15  0.143789  0.472142  0.519862  0.0  1.0  0.0
# 16  0.122256  0.492913  0.546630  0.0  1.0  0.0
# 17  0.115638  0.499936  0.555616  0.0  0.0  1.0
# 18  0.116109  0.499425  0.554963  0.0  0.0  1.0
# 19  0.132972  0.482212  0.532873  0.0  0.0  1.0

# %%
Y_pred_nro = np.argmax(y_pred,axis=1)  #-- conversión a entero
Y_true = np.argmax(y_train,axis=1)
print("%% aciertos X_train : %.3f" % accuracy_score(Y_true, Y_pred_nro))
report = classification_report(Y_true, Y_pred_nro)
# Out:
# % aciertos X_train : 0.683
# /home/walter/.virtualenvs/gen_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/walter/.virtualenvs/gen_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/walter/.virtualenvs/gen_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Confusion matrix TRAIN:\n%s" % report)
cm = confusion_matrix(Y_true, Y_pred_nro)
print("Confusion matrix:\n%s" % cm)
# Out:
# Confusion matrix TRAIN:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       0.00      0.00      0.00        38
#            2       0.51      1.00      0.67        39
#
#     accuracy                           0.68       120
#    macro avg       0.50      0.67      0.56       120
# weighted avg       0.52      0.68      0.58       120
#
# Confusion matrix:
# [[43  0  0]
#  [ 0  0 38]
#  [ 0  0 39]]

# %%
#--- TESTEO ---
Y_pred = model.predict(X_test)
Y_pred_nro = np.argmax(Y_pred,axis=1)  #-- conversión a entero

Y_true = np.argmax(y_test,axis=1)
print("%% aciertos X_test : %.3f" % accuracy_score(Y_true, Y_pred_nro))
report = classification_report(Y_true, Y_pred_nro)

print("Confusion matrix TEST:\n%s" % report)
cm = confusion_matrix(Y_true, Y_pred_nro)
print("Confusion matrix:\n%s" % cm)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# % aciertos X_test : 0.600
# Confusion matrix TEST:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.00      0.00      0.00        12
#            2       0.48      1.00      0.65        11
#
#     accuracy                           0.60        30
#    macro avg       0.49      0.67      0.55        30
# weighted avg       0.41      0.60      0.47        30
#
# Confusion matrix:
# [[ 7  0  0]
#  [ 0  0 12]
#  [ 0  0 11]]
# /home/walter/.virtualenvs/gen_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/walter/.virtualenvs/gen_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/walter/.virtualenvs/gen_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
